# %%
import scipy.io
import pandas as pd

# .mat 파일 로드
data = scipy.io.loadmat('../data/ARS_DLR_Benchmark_Data_Set.mat')

# 로드한 데이터 확인
print(data)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Wed Nov 11 17:10:05 2009', '__version__': '1.0', '__globals__': [], 'ARS_Paula_Benchmark_Sensor_Left': array([[array([[ 1.666000e+01, -9.749743e+00,  1.210670e+00, ...,  1.093977e+00,
#                 -1.109592e-01, -8.917303e-02],
#                [ 1.667000e+01, -9.749696e+00,  1.206152e+00, ...,  1.093379e+00,
#                 -1.055065e-01, -8.675934e-02],
#                [ 1.668000e+01, -9.749680e+00,  1.215991e+00, ...,  1.094462e+00,
#                 -1.051561e-01, -8.811755e-02],
#                ...,
#                [ 1.875200e+02, -9.249921e+00,  3.071002e+00, ...,  9.754031e-01,
#                 -6.981104e-01,  4.046410e-01],
#                [ 1.875300e+02, -9.235243e+00,  3.076077e+00, ...,  9.767420e-01,
#                 -6.998028e-01,  4.033662e-01],
#                [ 1.875400e+02, -9.244981e+00,  3.071420e+00, ...,  9.766901e-01,
# ...

# %%
print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'ARS_Paula_Benchmark_Sensor_Left', 'ARS_Sinja_Benchmark_Sensor_Left', 'ARS_Emil_Benchmark_Sensor_Right'])

# %%
# 데이터 프레임으로 변환
df_measurements = pd.DataFrame(data['ARS_Paula_Benchmark_Sensor_Left'][0][0])
df_attitude = pd.DataFrame(data['ARS_Paula_Benchmark_Sensor_Left'][0][1])
df_activities = pd.DataFrame(data['ARS_Paula_Benchmark_Sensor_Left'][0][2])
df_changes = pd.DataFrame(data['ARS_Paula_Benchmark_Sensor_Left'][0][3])

# 데이터 프레임 확인
print(df_measurements)
print(df_attitude)
print(df_activities)
print(df_changes)
# Out:
#             0         1         2         3         4         5         6
# 0       16.66 -9.749743  1.210670  0.343678 -0.025675 -0.005731 -0.008357  \
# 1       16.67 -9.749696  1.206152  0.314388 -0.002430 -0.023459  0.000644
# 2       16.68 -9.749680  1.215991  0.300021 -0.016867 -0.016598  0.010442
# 3       16.69 -9.747254  1.240182  0.300603 -0.006126 -0.005971  0.015086
# 4       16.70 -9.754563  1.264608  0.281624  0.011929 -0.002134  0.002716
# ...       ...       ...       ...       ...       ...       ...       ...
# 17084  187.50 -9.308542  3.048949  0.279144  0.009312 -0.021979  0.035354
# 17085  187.51 -9.288976  3.061353  0.248029  0.003899 -0.018511  0.038918
# 17086  187.52 -9.249921  3.071002  0.243824  0.011185 -0.016500  0.026434
# 17087  187.53 -9.235243  3.076077  0.219783  0.003964 -0.012185  0.031783
# 17088  187.54 -9.244981  3.071420  0.204973  0.000411 -0.019214  0.026331
#
#               7         8         9
# 0      1.093977 -0.110959 -0.089173
# ...

# %%
# 데이터 프레임으로 변환
df_measurements = pd.DataFrame(data['ARS_Paula_Benchmark_Sensor_Left'][0][0])
df_attitude = pd.DataFrame(data['ARS_Paula_Benchmark_Sensor_Left'][0][1])
df_activities = pd.DataFrame(data['ARS_Paula_Benchmark_Sensor_Left'][0][2])
df_changes = pd.DataFrame(data['ARS_Paula_Benchmark_Sensor_Left'][0][3])

# CSV 파일로 저장
df_measurements.to_csv('../data/measurements.csv', index=False)
df_attitude.to_csv('../data/attitude.csv', index=False)
df_activities.to_csv('../data/activities.csv', index=False)
df_changes.to_csv('../data/changes.csv', index=False)
